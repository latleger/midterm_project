# %%
import requests 
import json

# %%
import os
import requests

yelp_api_key = os.environ['yelp_key2']

# %%
URL = "https://api.yelp.com/v3/businesses/search" 

params = {
    "term": "restaurant, bars, entertainment",
    "location": "Austin, TX 78701",
    "categories": "bars, parking, entertainment",
    "radius": "1000",
    "limit": "10"
}

header_dict = {
    "Accept": "application/JSON",
    "Authorization": "Bearer " + yelp_api_key
}

response = requests.get(URL, params=params, headers=header_dict)
print(response.text)
# Out:
# {"businesses": [{"id": "2LvE0-abj3ULzy-KGxbcSQ", "alias": "antones-nightclub-austin-6", "name": "Antone's Nightclub", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/AbUrKiEOdzU2PbPHGrgOXg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/antones-nightclub-austin-6?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 120, "categories": [{"alias": "jazzandblues", "title": "Jazz & Blues"}, {"alias": "musicvenues", "title": "Music Venues"}, {"alias": "bars", "title": "Bars"}], "rating": 4.0, "coordinates": {"latitude": 30.2660523, "longitude": -97.7403876}, "transactions": [], "price": "$$", "location": {"address1": "305 E 5th", "address2": "", "address3": "", "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["305 E 5th", "Austin, TX 78701"]}, "phone": "+15128140361", "display_phone": "(512) 814-0361", "distance": 264.41345506199247}, {"id": "hJjnm0Vi_53sfqnAgQbFJQ", "alias": "zanzibar-austin-3", "name": "Zanzibar", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/5wqg1L73k91lwEGisgkIVg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/zanzibar-austin-3?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 391, "categories": [{"alias": "tikibars", "title": "Tiki Bars"}, {"alias": "lounges", "title": "Lounges"}], "rating": 4.0, "coordinates": {"latitude": 30.26273, "longitude": -97.74158}, "transactions": ["delivery"], "location": {"address1": "304 E Cesar Chavez St", "address2": "Unit 700", "address3": null, "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["304 E Cesar Chavez St", "Unit 700", "Austin, TX 78701"]}, "phone": "+17377876969", "display_phone": "(737) 787-6969", "distance": 515.6768777114245}, {"id": "eJ7X_8KXVlyHZtGrrLz4yg", "alias": "lamberts-downtown-barbecue-austin", "name": "Lamberts Downtown Barbecue", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Ezx4rMRvkMzptysSmiHusQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/lamberts-downtown-barbecue-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 1980, "categories": [{"alias": "bbq", "title": "Barbeque"}, {"alias": "bars", "title": "Bars"}, {"alias": "musicvenues", "title": "Music Venues"}], "rating": 4.0, "coordinates": {"latitude": 30.265235082587214, "longitude": -97.74790507437532}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "401 W 2nd St", "address2": "", "address3": "", "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["401 W 2nd St", "Austin, TX 78701"]}, "phone": "+15124941500", "display_phone": "(512) 494-1500", "distance": 538.8339982779863}, {"id": "vJvUga5XNBqjTrEEK7kI-Q", "alias": "the-roosevelt-room-austin", "name": "The Roosevelt Room", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/_DISOjs6Rg_4_Hd_CWu-Wg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-roosevelt-room-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 725, "categories": [{"alias": "cocktailbars", "title": "Cocktail Bars"}, {"alias": "venues", "title": "Venues & Event Spaces"}], "rating": 4.5, "coordinates": {"latitude": 30.2677, "longitude": -97.74627}, "transactions": [], "price": "$$$", "location": {"address1": "307 W 5th St", "address2": "Unit B", "address3": "", "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["307 W 5th St", "Unit B", "Austin, TX 78701"]}, "phone": "+15124944094", "display_phone": "(512) 494-4094", "distance": 340.57040865139163}, {"id": "cs6HfZNykLVitm09jWFqWg", "alias": "moonshine-patio-bar-and-gril ...

# %%
res_json = response.json()
res_json
res_json["businesses"]
# Out:
# [{'id': '2LvE0-abj3ULzy-KGxbcSQ',
#   'alias': 'antones-nightclub-austin-6',
#   'name': "Antone's Nightclub",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AbUrKiEOdzU2PbPHGrgOXg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/antones-nightclub-austin-6?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 120,
#   'categories': [{'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#    {'alias': 'musicvenues', 'title': 'Music Venues'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.2660523, 'longitude': -97.7403876},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '305 E 5th',
#    'address2': '',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['305 E 5th', 'Austin, TX 78701']},
#   'phone': '+15128140361',
#   'display_phone': '(512) 814-0361',
#   'distance': 264.41345506199247},
#  {'id': 'hJjnm0Vi_53sfqnAgQbFJQ',
#   'alias': 'zanzibar-austin-3',
#   'name': 'Zanzibar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5wqg1L73k91lwEGisgkIVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zanzibar-austin-3?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 391,
#   'categories': [{'alias': 'tikibars', 'title': 'Tiki Bars'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.26273, 'longitude': -97.74158},
#   'transactions': ['delivery'],
#   'location': {'address1': '304 E Cesar Chavez St',
#    'address2': 'Unit 700',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['304 E Cesar Chavez St',
#     'Unit 700',
#     'Austin, TX 78701']},
#   'phone': '+17377876969',
#   'display_phone': '(737) 787-6969',
#   'distance': 515.6768777114245},
#  {'id': 'eJ7X_8KXVlyHZtGrrLz4yg',
#   'alias': 'lamberts-downtown-barbecue-austin',
#   'name': 'Lamberts Downtown Barbecue',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ezx4rMRvkMzptysSmiHusQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lamberts-downtown-barbecue-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 1980,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'musicvenues', 'title': 'Music Venues'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.265235082587214,
#    'longitude': -97.74790507437532},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '401 W 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['401 W 2nd St', 'Austin, TX 78701']},
#   'phone': '+15124941500',
#   'display_phone': '(512) 494-1500',
#   'distance': 538.8339982779863},
#  {'id': 'vJvUga5XNBqjTrEEK7kI-Q',
#   'alias': 'the-roosevelt-room-austin',
#   'name': 'The Roosevelt Room',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_DISOjs6Rg_4_Hd_CWu-Wg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-roosevelt-room-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 725,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.2677, 'longitude': -97.74627},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '307 W 5th St',
#    'address2': 'Unit B',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['307 W 5th St', 'Unit B', 'Austin, TX 78701']},
#   'phone': '+15124944094',
#   'display_phone': '(512) 494-4094',
#   'distance': 340.57040865139163},
#  {'id': 'cs6HfZNykLVitm09jWFqWg',
#   'alias': 'moonshine-patio-bar-and-grill-austin',
#   'name': 'Moonshine Patio Bar & Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TfpTZFNSxyHCQroQ0z4o3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/moonshine-patio-bar-and-grill-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 5778,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.26375388334444,
#    'longitude': -97.73807686181601},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '303 Red River St',
#    'address2': '',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['303 Red River St', 'Austin, TX 78701']},
#   'phone': '+15122369599',
#   'display_phone': '(512) 236-9599',
#   'distance': 594.1939761599905},
#  {'id': '9KVCuq2uKldjhkg91V8C6g',
#   'alias': 'electric-shuffle-austin-austin',
#   'name': 'Electric Shuffle Austin',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A6RvdSIc3xtioEEXksKwyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/electric-shuffle-austin-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 50,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.260959879556598,
#    'longitude': -97.73882820000131},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '91 Red River St',
#    'address2': 'Ste 102',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['91 Red River St', 'Ste 102', 'Austin, TX 78701']},
#   'phone': '+15128948779',
#   'display_phone': '(512) 894-8779',
#   'distance': 793.0715756643933},
#  {'id': '_RYB1TIj4MeiBm63iLyxHg',
#   'alias': 'mort-subite-austin',
#   'name': 'Mort Subite',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tsQniQNdq8hxKgW4ipeYDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mort-subite-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 128,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.265719, 'longitude': -97.7439904},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '308 Congress Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['308 Congress Ave', 'Austin, TX 78701']},
#   'phone': '+15128615044',
#   'display_phone': '(512) 861-5044',
#   'distance': 202.98794494216742},
#  {'id': 'bFkja84hn6VVgaAVWrF4pQ',
#   'alias': 'here-nor-there-austin',
#   'name': 'Here Nor There',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yii_4KbEomgM2qmwGx0rmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/here-nor-there-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 250,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.26847, 'longitude': -97.74139},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '612 Brazos St',
#    'address2': '',
#    'address3': None,
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['612 Brazos St', 'Austin, TX 78701']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 181.53170297384648},
#  {'id': 'Ef-9J6ToOcrAJ6tL0Pn_HA',
#   'alias': 'midnight-cowboy-austin',
#   'name': 'Midnight Cowboy',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mu6IHz1gGVT7W3pzcX1ffg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/midnight-cowboy-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 515,
#   'categories': [{'alias': 'speakeasies', 'title': 'Speakeasies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.266983, 'longitude': -97.740028},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '313 E 6th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['313 E 6th St', 'Austin, TX 78701']},
#   'phone': '+15128432715',
#   'display_phone': '(512) 843-2715',
#   'distance': 271.2939416284979},
#  {'id': 'Ye1lObLkfsb5-QhdSJYo7Q',
#   'alias': 'corner-austin-5',
#   'name': 'Corner',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kcaEjq7g7zI4TdVL9QeWrg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-austin-5?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A',
#   'review_count': 786,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.264563, 'longitude': -97.743205},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '110 E Second St',
#    'address2': '',
#    'address3': '',
#    'city': 'Austin',
#    'zip_code': '78701',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['110 E Second St', 'Austin, TX 78701']},
#   'phone': '+15126084488',
#   'display_phone': '(512) 608-4488',
#   'distance': 297.09509688078464}]

# %%
import pandas as pd
import requests
import os

# Assuming you have a dataframe called 'austinbikes_df' with station data
yelp_key = os.environ['yelp_key2']

URL = "https://api.yelp.com/v3/businesses/search"

header_dict = {
    "Accept": "application/JSON",
    "Authorization": "Bearer " + yelp_key
}

a = []
b = []
c = []
d = []
e = []
f = []
g = []
h = []
j = []
m = []

    # Set parameters for Yelp API request
params = {
    "term": "restaurant, bars, entertainment",
    "location": "Austin, TX 78701",
    "categories": "bars, parking, entertainment",
    "radius": "1000",
    "limit": "10"
}

response = requests.get(URL, params=params, headers=header_dict)
res_json = response.json()

try:
    for i in res_json["businesses"]:
        a.append(i.get("name", None))  
        if "location" in i and "address1" in i["location"]:
             b.append(i["location"]["address1"]) 
             j.append(i["location"]["zip_code"])
        else:
             b.append(None)
             j.append(None)
        c.append(i.get("distance", None))  
        if "categories" in i and isinstance(i["categories"], list) and len(i["categories"]) > 0:
            d.append(i["categories"][0].get("title", None))  
        else:
            d.append(None)
        e.append(i.get("review_count", None))  
        f.append(i.get("rating", None))  
        g.append(i["coordinates"].get("longitude", None)) 
        h.append(i["coordinates"].get("latitude", None)) 
        m.append(i.get("price", None))
except:
    pass

yelp_df = pd.DataFrame({"name": a, "address": b, "distance": c, "category_name": d, "review_count": e, "rating": f, "longitude": g, "latitude": h, "postcode": j, "price": m})

# Print or do further processing with the dataframe 'yelp_df'
print(yelp_df)
# Out:
#                           name                address    distance  \
# 0           Antone's Nightclub              305 E 5th  264.413455
# 1                     Zanzibar  304 E Cesar Chavez St  515.676878
# 2   Lamberts Downtown Barbecue           401 W 2nd St  538.833998
# 3           The Roosevelt Room           307 W 5th St  340.570409
# 4  Moonshine Patio Bar & Grill       303 Red River St  594.193976
# 5      Electric Shuffle Austin        91 Red River St  793.071576
# 6                  Mort Subite       308 Congress Ave  202.987945
# 7               Here Nor There          612 Brazos St  181.531703
# 8             The Driskill Bar          604 Brazos St  185.540546
# 9              Midnight Cowboy           313 E 6th St  271.293942
#
#    category_name  review_count  rating  longitude   latitude postcode price
# 0   Jazz & Blues           120     4.0 -97.740388  30.266052    78701    $$
# 1      Tiki Bars           391     4.0 -97.741580  30.262730    78701  None
# 2       Barbeque          1980     4.0 -97.747905  30.265235    78701    $$
# 3  Cocktail Bars           725     4.5 -97.746270  30.267700    78701   $$$
# 4       Southern          5778     4.5 -97.738077  30.263754    78701    $$
# 5           Bars            50     4.5 -97.738828  30.260960    78701    $$
# 6           Pubs           128     4.5 -97.743990  30.265719    78701    $$
# 7  Cocktail Bars           250     4.5 -97.741390  30.268470    78701   $$$
# 8        Lounges           439     4.0 -97.741633  30.268558    78701    $$
# 9    Speakeasies           515     4.0 -97.740028  30.266983    78701    $$

# %%
import requests 
import json
import os
import pandas as pd

# %%
yelp_key = os.environ['yelp_key2']

# %%
import os
import requests

yelp_api_key = os.environ['yelp_key2']

# %%
URL = "https://api.yelp.com/v3/businesses/search" 

params = {
    "term": "restaurant, bars, entertainment",
    "location": "Austin, TX 78701",
    "categories": "bars, parking, entertainment",
    "radius": "1000",
    "limit": "10"
}

header_dict = {
    "Accept": "application/JSON",
    "Authorization": "Bearer " + yelp_api_key
}

response = requests.get(URL, params=params, headers=header_dict)
print(response.text)
# Out:
# {"businesses": [{"id": "2LvE0-abj3ULzy-KGxbcSQ", "alias": "antones-nightclub-austin-6", "name": "Antone's Nightclub", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/AbUrKiEOdzU2PbPHGrgOXg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/antones-nightclub-austin-6?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 120, "categories": [{"alias": "jazzandblues", "title": "Jazz & Blues"}, {"alias": "musicvenues", "title": "Music Venues"}, {"alias": "bars", "title": "Bars"}], "rating": 4.0, "coordinates": {"latitude": 30.2660523, "longitude": -97.7403876}, "transactions": [], "price": "$$", "location": {"address1": "305 E 5th", "address2": "", "address3": "", "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["305 E 5th", "Austin, TX 78701"]}, "phone": "+15128140361", "display_phone": "(512) 814-0361", "distance": 264.41345506199247}, {"id": "hJjnm0Vi_53sfqnAgQbFJQ", "alias": "zanzibar-austin-3", "name": "Zanzibar", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/5wqg1L73k91lwEGisgkIVg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/zanzibar-austin-3?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 391, "categories": [{"alias": "tikibars", "title": "Tiki Bars"}, {"alias": "lounges", "title": "Lounges"}], "rating": 4.0, "coordinates": {"latitude": 30.26273, "longitude": -97.74158}, "transactions": ["delivery"], "location": {"address1": "304 E Cesar Chavez St", "address2": "Unit 700", "address3": null, "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["304 E Cesar Chavez St", "Unit 700", "Austin, TX 78701"]}, "phone": "+17377876969", "display_phone": "(737) 787-6969", "distance": 515.6768777114245}, {"id": "eJ7X_8KXVlyHZtGrrLz4yg", "alias": "lamberts-downtown-barbecue-austin", "name": "Lamberts Downtown Barbecue", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Ezx4rMRvkMzptysSmiHusQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/lamberts-downtown-barbecue-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 1980, "categories": [{"alias": "bbq", "title": "Barbeque"}, {"alias": "bars", "title": "Bars"}, {"alias": "musicvenues", "title": "Music Venues"}], "rating": 4.0, "coordinates": {"latitude": 30.265235082587214, "longitude": -97.74790507437532}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "401 W 2nd St", "address2": "", "address3": "", "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["401 W 2nd St", "Austin, TX 78701"]}, "phone": "+15124941500", "display_phone": "(512) 494-1500", "distance": 538.8339982779863}, {"id": "vJvUga5XNBqjTrEEK7kI-Q", "alias": "the-roosevelt-room-austin", "name": "The Roosevelt Room", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/_DISOjs6Rg_4_Hd_CWu-Wg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-roosevelt-room-austin?adjust_creative=kPz8Z0G_dj_5_xxsv6OR5A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kPz8Z0G_dj_5_xxsv6OR5A", "review_count": 725, "categories": [{"alias": "cocktailbars", "title": "Cocktail Bars"}, {"alias": "venues", "title": "Venues & Event Spaces"}], "rating": 4.5, "coordinates": {"latitude": 30.2677, "longitude": -97.74627}, "transactions": [], "price": "$$$", "location": {"address1": "307 W 5th St", "address2": "Unit B", "address3": "", "city": "Austin", "zip_code": "78701", "country": "US", "state": "TX", "display_address": ["307 W 5th St", "Unit B", "Austin, TX 78701"]}, "phone": "+15124944094", "display_phone": "(512) 494-4094", "distance": 340.57040865139163}, {"id": "cs6HfZNykLVitm09jWFqWg", "alias": "moonshine-patio-bar-and-gril ...

# %%
import pandas as pd
import requests
import os

# Assuming you have a dataframe called 'austinbikes_df' with station data
yelp_key = os.environ['yelp_key2']

URL = "https://api.yelp.com/v3/businesses/search"

header_dict = {
    "Accept": "application/JSON",
    "Authorization": "Bearer " + yelp_key
}

a = []
b = []
c = []  
d = [] 
e = []  
f = []  
g = []
h = [] 
j = []
m = []
n = []

params = {
    "term": "restaurant, bars, entertainment",
    "location": "Austin, TX",
    "categories": "bars, parking, entertainment"
}

response = requests.get(URL, params=params, headers=header_dict)
res_json = response.json()

try:
    for i in res_json["businesses"]:
        a.append(i.get("name", None))  
        if "location" in i and "address1" in i["location"]:
             b.append(i["location"]["address1"]) 
             j.append(i["location"]["zip_code"])
        else:
             b.append(None)
             j.append(None)
        c.append(i.get("distance", None))  
        if "categories" in i and isinstance(i["categories"], list) and len(i["categories"]) > 0:
            d.append(i["categories"][0].get("title", None))  
        else:
            d.append(None)
        e.append(i.get("review_count", None))  
        f.append(i.get("rating", None))  
        g.append(i["coordinates"].get("longitude", None)) 
        h.append(i["coordinates"].get("latitude", None)) 
        m.append(i.get("price", None))
        n.append(i.get("id"))
except:
    pass

yelp_df = pd.DataFrame({"name": a, "address": b, "distance": c, "category_name": d, "review_count": e, "rating": f, "longitude": g, "latitude": h, "postcode": j, "price": m, "id":n})
yelp_df.head()
# Out:
#                          name              address     distance  \
# 0              Equipment Room        1101 Music Ln  6182.622950
# 1     Electric Shuffle Austin      91 Red River St  5381.452058
# 2                Aba - Austin  1011 S Congress Ave  6094.825567
# 3  The Little Longhorn Saloon       5434 Burnet Rd  2563.022276
# 4         Dive Bar and Lounge    1703 Guadalupe St  3284.400072
#
#    category_name  review_count  rating  longitude   latitude postcode price  \
# 0    Speakeasies            21     4.5 -97.747718  30.252693    78704  None
# 1           Bars            51     4.5 -97.738828  30.260960    78701    $$
# 2  Mediterranean          1089     4.5 -97.748030  30.253570    78704  None
# 3      Dive Bars           239     4.5 -97.740132  30.329339    78756     $
# 4      Dive Bars           174     4.5 -97.741950  30.279710    78701     $
#
#                        id
# 0  lhdlHFbXlZhs1VfU5z0HoQ
# 1  9KVCuq2uKldjhkg91V8C6g
# 2  GwAFL29gpnEIjAG9MauMig
# 3  wRitGLmWK86di83q6o8lCA
# 4  TRMSNc6MM_YRzT1YnaEmWA

# %% [markdown]
# export the yelp dataframe into csv

# %%
yelp_df.to_csv("yelp_data.csv", index = False)

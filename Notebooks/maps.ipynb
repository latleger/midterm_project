# %%
# imports
import pandas as pd
import folium

# %%
# bike station info
bike_data = 'austin_stations.csv'
austin_stations = pd.read_csv(bike_data)

# points of interests
yelp_data = 'yelp_info.csv'
yelp_locations = pd.read_csv(yelp_data)

# additional points of interests
add_yelp = 'yelp_data.csv'
add_locations = pd.read_csv(add_yelp)

# transit stops
transit_data = 'Stops.csv'
transit_locations = pd.read_csv(transit_data)
fitered_locations = transit_locations[transit_locations['ZIP'] == 78701]

# %%
# Create a map of downtown Austin
map = folium.Map(location=[30.2672, -97.7387], zoom_start=14)

# %%
# Add markers for bike stations
for index, row in austin_stations.iterrows():
    latitude = row['Latitude']
    longitude = row['Longitude']
    coords = [latitude, longitude]
    
    # Create a custom icon with the desired color and "font awesome"
    icon = folium.Icon(color='red', icon='bicycle', prefix='fa')
    
    # Add the marker with the custom icon to the map
    folium.Marker(coords, popup=f"Bike Station\nAvailable Bikes: {row['Available_Bikes']}", icon=icon).add_to(map)

# %%
# Add markers for points of interest
for index, row in yelp_locations.iterrows():
    latitude = row['yelp_latitude']
    longitude = row['yelp_longitude']
    coords = [latitude, longitude]  
    folium.Marker(coords, popup=row['name']).add_to(map)

# %%
# Add markers for additional points of interest
for index, row in add_locations.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    coords = [latitude, longitude]  
    folium.Marker(coords, popup=row['name']).add_to(map)

# %%
# Add markers for bus stops
for index, row in fitered_locations.iterrows():
    latitude = row['LATITUDE']
    longitude = row['LONGITUDE']
    coords = [latitude, longitude]
    
    # Create a custom icon with the desired color and "font awesome"
    icon = folium.Icon(color='purple', icon='bus', prefix='fa')
    
    folium.Marker(coords, popup=f"Stop ID: {row['STOP_ID']}", icon=icon).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b5e0af80e3c3d9bb26830102932ef51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b5e0af80e3c3d9bb26830102932ef51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b5e0af80e3c3d9bb26830102932ef51 = L.map(
#                 &quot;map_3b5e0af80e3c3d9bb26830102932ef51&quot;,
#                 {
#                     center: [30.2672, -97.7387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31260e2a30398fdfd3ef2e129457d192 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b5e0af80e3c3d9bb26830102932ef51);
#
#
#             var marker_5bc1be0b64380a97d2ab26f60a45fc5e = L.marker(
#                 [30.25759, -97.74898],
#                 {}
#             ).addTo(map_3b5e0af80e3c3d9bb26830102932ef51);
#
#
#             var icon_a94c7fdbc7be0773ef1c1ebfb4ded2b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5bc1be0b64380a97d2ab26f60a45fc5e.setIcon(icon_a94c7fdbc7be0773ef1c1ebfb4ded2b6);
#
#
#         var popup_6464a1f9b316e499acde9330d630b2dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc705a471ec102693100c46a3e8befdd = $(`&lt;div id=&quot;html_fc705a471ec102693100c46a3e8befdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bike Station Available Bikes: 7&lt;/div&gt;`)[0];
#                 popup_6464a1f9b316e499acde9330d630b2dd.setContent(html_fc705a471ec102693100c46a3e8befdd);
#
#
#
#         marker_5bc1be0b64380a97d2ab26f60a45fc5e.bindPopup(popup_6464a1f9b316e499acde9330d630b2dd)
#         ;
#
#
#
#
#             var marker_65006f3bb16a17367554918e68975d7c = L.marker(
#                 [30.29312, -97.74412],
#                 {}
#             ).addTo(map_3b5e0af80e3c3d9bb26830102932ef51);
#
#
#             var icon_60cb23861bb1f133d8b940f22961facb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_65006f3bb16a17367554918e68975d7c.setIcon(icon_60cb23861bb1f133d8b940f22961facb);
#
#
#         var popup_31dfb889d355937891a044764b59b2e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_208ab2020b3162f87dd7bcc943b4c9cf = $(`&lt;div id=&quot;html_208ab2020b3162f87dd7bcc943b4c9cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bike Station Available Bikes: 3&lt;/div&gt;`)[0];
#                 popup_31dfb889d355937891a044764b59b2e6.setContent(html_208ab2020b3162f87dd7bcc943b4c9cf);
#
#
#
#         marker_65006f3bb16a17367554918e68975d7c.bindPopup(popup_31dfb889d355937891a044764b59b2e6)
#         ;
#
#
#
#
#             var marker_f951b42a9ce3c5aaf78679a5a9e823a7 = L.marker(
#                 [30.2854, -97.74673],
#                 {}
#             ).addTo(map_3b5e0af80e3c3d9bb26830102932ef51);
#
#
#             var icon_ff1419c24745ab464c31248c0d4286f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f951b42a9ce3c5aaf78679a5a9e823a7.setIcon(icon_ff1419c24745ab464c31248c0d4286f3);
#
#
#         var popup_1c90c6a06e6957a1d01bcc8e915244a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac071cb58d35fd7782a71af3677a9c5f = $(`&lt;div id=&quot;html_ac071cb58d35fd7782a71af3677a9c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bike Station Available Bikes: 2&lt;/div&gt;`)[0];
#                 popup_1c90c6a06e6957a1d01bcc8e915244a3.setContent(html_ac071cb58d35fd7782a71af3677a9c5f);
#
#
#
#         marker_f951b42a9ce3c5aaf78679a5a9e823a7.bindPopup(popup_1c90c6a06e6957a1d01bcc8e915244a3)
#         ;
#
#
#
#
#             var marker_2ad42aede600d2a1c52cc8a7d360da58 = L.marker(
#                 [30.27217, -97.75246],
#                 {}
#             ).addTo(map_3b5e0af80e3c3d9bb26830102932ef51);
#
#
#             var icon_f5de376f6addd92e7442c84de500c2af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon
